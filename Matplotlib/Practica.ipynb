# %% [markdown]
# **Practicaremos lo aprendido de matplotlib**

# %%
#Importar la librerias pandas, matplotlib y numpy
import pandas as pd
import os
# Ver ruta actual
os.chdir(r"C:\Users\monti.UNITY12\OneDrive\Documentos\Curso Python 2026")

# %%
#Importar un archivo csv llamado accidentes.csv
df = pd.read_csv("accidentes.csv")
df
# Out:
#        Estado Nombre de Estado  Numero de Caso  Peatones  \
# 0           1          Alabama           10001         0
# 1           1          Alabama           10002         0
# 2           1          Alabama           10003         0
# 3           1          Alabama           10004         0
# 4           1          Alabama           10005         1
# ...       ...              ...             ...       ...
# 39216      56          Wyoming          560114         0
# 39217      56          Wyoming          560115         0
# 39218      56          Wyoming          560116         0
# 39219      56          Wyoming          560117         0
# 39220      56          Wyoming          560118         0
#
#        Personas _no_vehiculos  Vehiculos automotores  Vehiculos estacionados  \
# 0                           0                      2                       0
# 1                           0                      2                       0
# 2                           0                      1                       0
# 3                           0                      1                       0
# 4                           1                      1                       0
# ...                       ...                    ...                     ...
# 39216                       0                      2                       0
# 39217                       0                      1                       0
# 39218                       0                      1                       0
# 39219                       0                      1                       0
# 39220                       0                      1                       0
#
#        Condado    Nombre Condado  Ciudad  ...      Clima  Autobus Escolar  \
# 0          107     PICKENS (107)       0  ...  Despejado               No
# 1          101  MONTGOMERY (101)       0  ...  Despejado               No
# 2          115   ST. CLAIR (115)       0  ...    Nublado               No
# 3          101  MONTGOMERY (101)       0  ...    Nublado               No
# 4           73    JEFFERSON (73)       0  ...     lluvia               No
# ...        ...               ...     ...  ...        ...              ...
# 39216       37   SWEETWATER (37)     730  ...  Despejado               No
# 39217       23      LINCOLN (23)       0  ...      Nieve               No
# 39218       21      LARAMIE (21)     100  ...      Nieve               No
# 39219       19      JOHNSON (19)       0  ...      Nieve               No
# 39220       21      LARAMIE (21)       0  ...  Despejado               No
#
#       Cruce de Trenes  Hora Notificacion  Minuto Notificacion  Hora Llegada  \
# 0           NO APLICA                 12                   47            13
# 1           NO APLICA                 99                   99            99
# 2           NO APLICA                  1                   33             1
# 3           NO APLICA                 14                   48            15
# 4           NO APLICA                 18                   48            18
# ...               ...                ...                  ...           ...
# 39216       NO APLICA                 11                   30            11
# 39217       NO APLICA                 99                   98            99
# 39218       NO APLICA                 15                    2            15
# 39219       NO APLICA                  7                   24             7
# 39220       NO APLICA                  5                    6             5
#
#        Minuto Llegada Decesos       Fecha PersonaVehiculo
# 0                   4       1  01/01/2022               3
# 1                  99       2  01/01/2022               5
# 2                  50       1  01/01/2022               2
# 3                   9       1  02/01/2022               1
# 4                  54       1  02/01/2022               1
# ...               ...     ...         ...             ...
# 39216              35       1  27/12/2022               2
# 39217              98       1  24/10/2022               1
# 39218               7       1  21/12/2022               1
# 39219              40       1  22/12/2022               1
# 39220              25       1  17/12/2022               4
#
# [39221 rows x 45 columns]
