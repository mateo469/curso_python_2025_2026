# %% [markdown]
# **Practicaremos lo aprendido de matplotlib**

# %%
#Importar la librerias pandas, matplotlib y numpy
import matplotlib.pyplot as plt
import pandas as pd
import os
# Ver ruta actual
os.chdir(r"C:\Users\monti.UNITY12\OneDrive\Documentos\Curso Python 2026")

# %%
#Importar un archivo csv llamado accidentes.csv
df = pd.read_csv("accidentes.csv", index_col='NumeroCaso')
df
# Out:
#             Estado NombreEstado  Peatones  Personas _no_vehiculos  \
# NumeroCaso
# 10001            1      Alabama         0                       0
# 10002            1      Alabama         0                       0
# 10003            1      Alabama         0                       0
# 10004            1      Alabama         0                       0
# 10005            1      Alabama         1                       1
# ...            ...          ...       ...                     ...
# 560114          56      Wyoming         0                       0
# 560115          56      Wyoming         0                       0
# 560116          56      Wyoming         0                       0
# 560117          56      Wyoming         0                       0
# 560118          56      Wyoming         0                       0
#
#             Vehiculos automotores  VehiculosEstacionados  Condado  \
# NumeroCaso
# 10001                           2                      0      107
# 10002                           2                      0      101
# 10003                           1                      0      115
# 10004                           1                      0      101
# 10005                           1                      0       73
# ...                           ...                    ...      ...
# 560114                          2                      0       37
# 560115                          1                      0       23
# 560116                          1                      0       21
# 560117                          1                      0       19
# 560118                          1                      0       21
#
#                NombreCondado  Ciudad  NombreCiudad  ...      Clima  \
# NumeroCaso                                          ...
# 10001          PICKENS (107)       0     NO APLICA  ...  Despejado
# 10002       MONTGOMERY (101)       0     NO APLICA  ...  Despejado
# 10003        ST. CLAIR (115)       0     NO APLICA  ...    Nublado
# 10004       MONTGOMERY (101)       0     NO APLICA  ...    Nublado
# 10005         JEFFERSON (73)       0     NO APLICA  ...     lluvia
# ...                      ...     ...           ...  ...        ...
# 560114       SWEETWATER (37)     730  ROCK SPRINGS  ...  Despejado
# 560115          LINCOLN (23)       0     NO APLICA  ...      Nieve
# 560116          LARAMIE (21)     100      CHEYENNE  ...      Nieve
# 560117          JOHNSON (19)       0     NO APLICA  ...      Nieve
# 560118          LARAMIE (21)       0     NO APLICA  ...  Despejado
#
#            Autobus Escolar  Cruce de Trenes  Hora Notificacion  \
# NumeroCaso
# 10001                   No        NO APLICA                 12
# 10002                   No        NO APLICA                 99
# 10003                   No        NO APLICA                  1
# 10004                   No        NO APLICA                 14
# 10005                   No        NO APLICA                 18
# ...                    ...              ...                ...
# 560114                  No        NO APLICA                 11
# 560115                  No        NO APLICA                 99
# 560116                  No        NO APLICA                 15
# 560117                  No        NO APLICA                  7
# 560118                  No        NO APLICA                  5
#
#             Minuto Notificacion Hora Llegada  Minuto Llegada Decesos  \
# NumeroCaso
# 10001                        47           13               4       1
# 10002                        99           99              99       2
# 10003                        33            1              50       1
# 10004                        48           15               9       1
# 10005                        48           18              54       1
# ...                         ...          ...             ...     ...
# 560114                       30           11              35       1
# 560115                       98           99              98       1
# 560116                        2           15               7       1
# 560117                       24            7              40       1
# 560118                        6            5              25       1
#
#                  Fecha PersonaVehiculo
# NumeroCaso
# 10001       01/01/2022               3
# 10002       01/01/2022               5
# 10003       01/01/2022               2
# 10004       02/01/2022               1
# 10005       02/01/2022               1
# ...                ...             ...
# 560114      27/12/2022               2
# 560115      24/10/2022               1
# 560116      21/12/2022               1
# 560117      22/12/2022               1
# 560118      17/12/2022               4
#
# [39221 rows x 42 columns]

# %%
#Mostrar los primeros elementos
df.head()
# Out:
#             Estado NombreEstado  Peatones  Personas _no_vehiculos  \
# NumeroCaso
# 10001            1      Alabama         0                       0
# 10002            1      Alabama         0                       0
# 10003            1      Alabama         0                       0
# 10004            1      Alabama         0                       0
# 10005            1      Alabama         1                       1
#
#             Vehiculos automotores  VehiculosEstacionados  Condado  \
# NumeroCaso
# 10001                           2                      0      107
# 10002                           2                      0      101
# 10003                           1                      0      115
# 10004                           1                      0      101
# 10005                           1                      0       73
#
#                NombreCondado  Ciudad NombreCiudad  ...      Clima  \
# NumeroCaso                                         ...
# 10001          PICKENS (107)       0    NO APLICA  ...  Despejado
# 10002       MONTGOMERY (101)       0    NO APLICA  ...  Despejado
# 10003        ST. CLAIR (115)       0    NO APLICA  ...    Nublado
# 10004       MONTGOMERY (101)       0    NO APLICA  ...    Nublado
# 10005         JEFFERSON (73)       0    NO APLICA  ...     lluvia
#
#            Autobus Escolar  Cruce de Trenes  Hora Notificacion  \
# NumeroCaso
# 10001                   No        NO APLICA                 12
# 10002                   No        NO APLICA                 99
# 10003                   No        NO APLICA                  1
# 10004                   No        NO APLICA                 14
# 10005                   No        NO APLICA                 18
#
#             Minuto Notificacion Hora Llegada  Minuto Llegada Decesos  \
# NumeroCaso
# 10001                        47           13               4       1
# 10002                        99           99              99       2
# 10003                        33            1              50       1
# 10004                        48           15               9       1
# 10005                        48           18              54       1
#
#                  Fecha PersonaVehiculo
# NumeroCaso
# 10001       01/01/2022               3
# 10002       01/01/2022               5
# 10003       01/01/2022               2
# 10004       02/01/2022               1
# 10005       02/01/2022               1
#
# [5 rows x 42 columns]
