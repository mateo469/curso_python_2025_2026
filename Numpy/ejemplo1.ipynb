# %%
precios
# Out:
# array([2.5 , 3.75, 4.5 , 5.  , 6.  , 6.  ])

# %%
#Eliminar un elemento de la lista
precios = np.delete(precios, 1)

# %%
#Agregar un elemento a la lista
precios = np.append(precios, 6)
precios
# Out:
# array([2.5 , 0.3 , 3.75, 4.5 , 5.  , 6.  , 6.  ])

# %%
#seleccionar un valor de la lista
precios[1]
# Out:
# np.float64(0.3)

# %%
precios + 3
# Out:
# array([5.5 , 3.3 , 6.75, 7.5 , 8.  ])

# %%
precios = np.array(precios)
precios
# Out:
# array([2.5 , 0.3 , 3.75, 4.5 , 5.  ])

# %%
precios = [2.5, 0.3, 3.75, 4.5, 5.0]
precios
# Out:
# [2.5, 0.3, 3.75, 4.5, 5.0]

# %%
import numpy as np
