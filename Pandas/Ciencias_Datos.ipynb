# %% [markdown]
# #Totalmente desde cero

# %%
#Importar la libreria de pandas
import pandas as pd

# %%
#Crear un dataframe con un diccionario de informacion.
datos = {
    'id': [1, 2, 3, 4, 5, 6],
    'nombre': ['Juan', 'Ana', 'Camila', 'Salome', 'Sharis Gongora', 'Melissa'],
    'edad': [25, 30, 22, 23, 34, 21],
    'estado': ['Tabasco', 'Tabasco', 'Chiapas', 'Veracruz', 'Tabasco', 'Veracruz'],
    'calificacion': [6, 9.5, 8.9, 6, 9, 10],
    'salario': [10000, 20000, 15000, 12000, 30000, 18000],
    'impuesto': [0.16, 0.16, 0.16, 0.16, 0.16, 0.16], # 16% de IVA
    'peso':[70, 60, 55, 58, 65, 50],  # en kg
     'estatura':[1.75, 1.60, 1.65, 1.68, 1.70, 1.55]  # en metros
    
}
#Convertirlo a un dataframe
tabla_datos = pd.DataFrame(datos).set_index('id')
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6          Melissa    21  Veracruz          10.0    18000      0.16    50
#
#     estatura
# id
# 1       1.75
# 2       1.60
# 3       1.65
# 4       1.68
# 5       1.70
# 6       1.55

# %%
#Mostrar las primeras 5 filas del dataframe
tabla_datos.head()
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
#
#     estatura
# id
# 1       1.75
# 2       1.60
# 3       1.65
# 4       1.68
# 5       1.70

# %%
#Mostrar las ultimas filas
tabla_datos.tail(3)
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6          Melissa    21  Veracruz          10.0    18000      0.16    50
#
#     estatura
# id
# 4       1.68
# 5       1.70
# 6       1.55

# %%
#Ordenar el dataframe por nombre
tabla_datos.sort_values(by='estado', ascending=True, inplace=False)
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 6          Melissa    21  Veracruz          10.0    18000      0.16    50
#
#     estatura
# id
# 3       1.65
# 1       1.75
# 2       1.60
# 5       1.70
# 4       1.68
# 6       1.55

# %%
#Acceder a los ementos del dataframe
tabla_datos[['nombre', 'estado']].head(3)
# Out:
#     nombre   estado
# id
# 1     Juan  Tabasco
# 2      Ana  Tabasco
# 3   Camila  Chiapas

# %%
#Mostrar la descripcion del dataframe
tabla_datos.describe()
# Out:
#             edad  calificacion     salario  impuesto       peso  estatura
# count   6.000000      6.000000      6.0000      6.00   6.000000  6.000000
# mean   25.833333      8.233333  17500.0000      0.16  59.666667  1.655000
# std     5.115336      1.773885   7148.4264      0.00   7.118052  0.071764
# min    21.000000      6.000000  10000.0000      0.16  50.000000  1.550000
# 25%    22.250000      6.725000  12750.0000      0.16  55.750000  1.612500
# 50%    24.000000      8.950000  16500.0000      0.16  59.000000  1.665000
# 75%    28.750000      9.375000  19500.0000      0.16  63.750000  1.695000
# max    34.000000     10.000000  30000.0000      0.16  70.000000  1.750000

# %%
#Filtrar informacion por estado.
tabla_datos[tabla_datos['estado']== 'Tabasco']
# Out:
#             nombre  edad   estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25  Tabasco           6.0    10000      0.16    70
# 2              Ana    30  Tabasco           9.5    20000      0.16    60
# 5   Sharis Gongora    34  Tabasco           9.0    30000      0.16    65
#
#     estatura
# id
# 1       1.75
# 2       1.60
# 5       1.70

# %%
#Mostrar tolas las calificaciones mayores a 8
tabla_datos[tabla_datos['calificacion'] < 8]
# Out:
#     nombre  edad    estado  calificacion  salario  impuesto  peso  estatura
# id
# 1     Juan    25   Tabasco           6.0    10000      0.16    70      1.75
# 4   Salome    23  Veracruz           6.0    12000      0.16    58      1.68

# %%
#Agregar una nueva columna con informacion
tabla_datos['sexo'] = ['M', 'F', 'F', 'F', 'F', 'F']
#Agregar otra nueva columna

tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6          Melissa    21  Veracruz          10.0    18000      0.16    50
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 3       1.65    F
# 4       1.68    F
# 5       1.70    F
# 6       1.55    F

# %%
#Agregar nuevos nombres
tabla_datos.loc[7] = ['Jose', 22, 'Veracruz', 5.5, 21000, 0.16, 75, 1.66, 'M']
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6          Melissa    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 3       1.65    F
# 4       1.68    F
# 5       1.70    F
# 6       1.55    F
# 7       1.66    M

# %%
#Mostrar la informacion del dataframe
tabla_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 1 to 7
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        7 non-null      object
#  1   edad          7 non-null      int64
#  2   estado        7 non-null      object
#  3   calificacion  7 non-null      float64
#  4   salario       7 non-null      int64
#  5   impuesto      7 non-null      float64
#  6   peso          7 non-null      int64
#  7   estatura      7 non-null      float64
#  8   sexo          7 non-null      object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 560.0+ bytes

# %%
#Modificar el nombre de Melissa atraves de su id
tabla_datos.loc[6, 'nombre'] = 'Mish Frances'
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 3       1.65    F
# 4       1.68    F
# 5       1.70    F
# 6       1.55    F
# 7       1.66    M

# %%
#Eliminar celdas vacias
tabla_datos.dropna()
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 3       1.65    F
# 4       1.68    F
# 5       1.70    F
# 6       1.55    F
# 7       1.66    M

# %%
#Rellenar celdas vacias con un valor
tabla_datos.fillna(0)
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 3       1.65    F
# 4       1.68    F
# 5       1.70    F
# 6       1.55    F
# 7       1.66    M

# %%
#filtrar filas por indices
tabla_datos.iloc[0:3]
# Out:
#     nombre  edad   estado  calificacion  salario  impuesto  peso  estatura  \
# id
# 1     Juan    25  Tabasco           6.0    10000      0.16    70      1.75
# 2      Ana    30  Tabasco           9.5    20000      0.16    60      1.60
# 3   Camila    22  Chiapas           8.9    15000      0.16    55      1.65
#
#    sexo
# id
# 1     M
# 2     F
# 3     F

# %%
#Filtrar filas y columnas deseadas a mostrar
tabla_datos.loc[[1,4],['nombre', 'estado', 'salario']]
# Out:
#     nombre    estado  salario
# id
# 1     Juan   Tabasco    10000
# 4   Salome  Veracruz    12000

# %%
#filtrar informacion por condiciones
tabla_datos[tabla_datos['edad'] > 24]
# Out:
#             nombre  edad   estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25  Tabasco           6.0    10000      0.16    70
# 2              Ana    30  Tabasco           9.5    20000      0.16    60
# 5   Sharis Gongora    34  Tabasco           9.0    30000      0.16    65
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 5       1.70    F

# %%
#filtar informacion por cadenas de texto que contenga palabras especificas
tabla_datos[tabla_datos['estado'].str.contains('as')]
# Out:
#             nombre  edad   estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25  Tabasco           6.0    10000      0.16    70
# 2              Ana    30  Tabasco           9.5    20000      0.16    60
# 3           Camila    22  Chiapas           8.9    15000      0.16    55
# 5   Sharis Gongora    34  Tabasco           9.0    30000      0.16    65
#
#     estatura sexo
# id
# 1       1.75    M
# 2       1.60    F
# 3       1.65    F
# 5       1.70    F

# %%
#Agregar una nueva columnas de calorias de cada persona
tabla_datos['calorias']=[2000, 1800, 2000, 1400, 2500, 1600, 1000]
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo  calorias
# id
# 1       1.75    M      2000
# 2       1.60    F      1800
# 3       1.65    F      2000
# 4       1.68    F      1400
# 5       1.70    F      2500
# 6       1.55    F      1600
# 7       1.66    M      1000

# %%
#Eliminar filas con valores faltantes
tabla_datos.dropna()
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo  calorias
# id
# 1       1.75    M      2000
# 2       1.60    F      1800
# 3       1.65    F      2000
# 4       1.68    F      1400
# 5       1.70    F      2500
# 6       1.55    F      1600
# 7       1.66    M      1000

# %%
#Agregar nuevo registros de informacion
tabla_datos.loc[8] = ['Amador', 66, 'Jalisco', 9.5, 50000, 0.16, 60, 1.64, 'M', 2500]
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
# 8           Amador    66   Jalisco           9.5    50000      0.16    60
#
#     estatura sexo  calorias
# id
# 1       1.75    M      2000
# 2       1.60    F      1800
# 3       1.65    F      2000
# 4       1.68    F      1400
# 5       1.70    F      2500
# 6       1.55    F      1600
# 7       1.66    M      1000
# 8       1.64    M      2500

# %%
#Filtrar informacion con condiciones
tabla_datos[(tabla_datos['estado'] == 'Tabasco') & (tabla_datos['salario'] > 12000)]
# Out:
#             nombre  edad   estado  calificacion  salario  impuesto  peso  \
# id
# 2              Ana    30  Tabasco           9.5    20000      0.16    60
# 5   Sharis Gongora    34  Tabasco           9.0    30000      0.16    65
#
#     estatura sexo  calorias
# id
# 2        1.6    F      1800
# 5        1.7    F      2500

# %%
#Filtrar por un valor dentro de una lista
#📌 Ejemplo: personas que están en Chiapas o Tabasco
tabla_datos[tabla_datos['estado'].isin(['Chiapas', 'Tabasco'])]
# Out:
#             nombre  edad   estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25  Tabasco           6.0    10000      0.16    70
# 2              Ana    30  Tabasco           9.5    20000      0.16    60
# 3           Camila    22  Chiapas           8.9    15000      0.16    55
# 5   Sharis Gongora    34  Tabasco           9.0    30000      0.16    65
#
#     estatura sexo  calorias
# id
# 1       1.75    M      2000
# 2       1.60    F      1800
# 3       1.65    F      2000
# 5       1.70    F      2500

# %%
#Filtrar porindices, el primer y el ultimo elemento.
tabla_datos.iloc[[0, -1]]
# Out:
#     nombre  edad   estado  calificacion  salario  impuesto  peso  estatura  \
# id
# 1     Juan    25  Tabasco           6.0    10000      0.16    70      1.75
# 8   Amador    66  Jalisco           9.5    50000      0.16    60      1.64
#
#    sexo  calorias
# id
# 1     M      2000
# 8     M      2500

# %%
#filtrar los salarios mayores a 15000, y mostrar solo el nombre, estado, salario
tabla_datos[tabla_datos['salario'] > 10000][['nombre', 'salario', 'estado']]
# Out:
#             nombre  salario    estado
# id
# 2              Ana    20000   Tabasco
# 3           Camila    15000   Chiapas
# 4           Salome    12000  Veracruz
# 5   Sharis Gongora    30000   Tabasco
# 6     Mish Frances    18000  Veracruz
# 7             Jose    21000  Veracruz
# 8           Amador    50000   Jalisco

# %%
#Calcular el salrio neto descontando el impuesto
tabla_datos['salario_neto']= tabla_datos['salario']*(1 - tabla_datos['impuesto'])
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
# 8           Amador    66   Jalisco           9.5    50000      0.16    60
#
#     estatura sexo  calorias  salario_neto
# id
# 1       1.75    M      2000        8400.0
# 2       1.60    F      1800       16800.0
# 3       1.65    F      2000       12600.0
# 4       1.68    F      1400       10080.0
# 5       1.70    F      2500       25200.0
# ...

# %%
#calacular el indice de la masa corporal(IMC)
tabla_datos['IMC']= tabla_datos['peso'] / (tabla_datos['estatura'] ** 2)
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
# 8           Amador    66   Jalisco           9.5    50000      0.16    60
#
#     estatura sexo  calorias  salario_neto        IMC
# id
# 1       1.75    M      2000        8400.0  22.857143
# 2       1.60    F      1800       16800.0  23.437500
# 3       1.65    F      2000       12600.0  20.202020
# 4       1.68    F      1400       10080.0  20.549887
# ...

# %%
#Promedio de la edad
tabla_datos['edad'].mean()
#tabla_datos.to_csv('documento.csv', index=True)
# Out:
# np.float64(30.375)

# %%
#suma del salario
tabla_datos['salario'].sum()
# Out:
# np.int64(176000)

# %%
#Salario maximo
tabla_datos['salario'].max()
# Out:
# np.int64(50000)

# %%
#Salario minimo
tabla_datos['salario'].min()
# Out:
# np.int64(10000)

# %%
#Agrupar y convertir en un DataFrame ordenado
#Si quieres obtener un nuevo DataFrame:
tab1 = tabla_datos.groupby('estado')['salario'].mean().reset_index()
tab1
# Out:
#      estado  salario
# 0   Chiapas  15000.0
# 1   Jalisco  50000.0
# 2   Tabasco  20000.0
# 3  Veracruz  17000.0

# %% [markdown]
# **Tablas Dinamicas**
#
# Crear tablas dinámicas (o pivot tables) con pandas es muy sencillo usando la función pivot_table(). Es muy parecida a las tablas dinámicas de Excel y se usan para resumir y analizar datos agrupados.
#
# ## Estructura de una tabla dinamica.
#
# ##### pd.pivot_table(data=df, values='columna_valor', index='columna_fila', columns='columna_columna', aggfunc='función')

# %%
#Mi primer tabla dinamica basica
#Tabla dinámica del salario promedio por estado
tabla1 = pd.pivot_table(tabla_datos, values='salario', index='estado', aggfunc='mean')
tabla1
# Out:
#           salario
# estado
# Chiapas   15000.0
# Jalisco   50000.0
# Tabasco   20000.0
# Veracruz  17000.0

# %%
#Contar cuantas personas hay por estados
tabla2 = pd.pivot_table(tabla_datos, values='nombre', index='estado', aggfunc='count')
tabla2
# Out:
#           nombre
# estado
# Chiapas        1
# Jalisco        1
# Tabasco        3
# Veracruz       3

# %%
tabla4 = pd.pivot_table(tabla_datos, index='estado', values=['salario', 'edad', 'calificacion'], aggfunc=['mean', 'max', 'min'])
tabla4
#Guardarlo en un archivo csv
#tabla4.to_csv('tabladinamica.csv')
# Out:
#                  mean                              max               \
#          calificacion       edad  salario calificacion edad salario
# estado
# Chiapas      8.900000  22.000000  15000.0          8.9   22   15000
# Jalisco      9.500000  66.000000  50000.0          9.5   66   50000
# Tabasco      8.166667  29.666667  20000.0          9.5   34   30000
# Veracruz     7.166667  22.000000  17000.0         10.0   23   21000
#
#                   min
#          calificacion edad salario
# estado
# Chiapas           8.9   22   15000
# Jalisco           9.5   66   50000
# Tabasco           6.0   25   10000
# Veracruz          5.5   21   12000

# %%
import matplotlib.pyplot as plt

tabla = pd.pivot_table(tabla_datos, values='salario', index='estado', aggfunc='mean')

# Crear gráfico de barras
tabla.plot(kind='bar', legend=False)
plt.title('Salario promedio por estado')
plt.ylabel('Salario')
plt.xlabel('Estado')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Grafica de lineas.
tabla = pd.pivot_table(tabla_datos, values='calificacion', index='estado', aggfunc='mean')

# Gráfico de líneas
tabla.plot(kind='line', marker='o')
plt.title('Calificación promedio por estado')
plt.ylabel('Calificación')
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
#Añadir nueva columna
tabla_datos['Tiene Licencia'] = ['si', 'no', 'si', 'no', 'si', 'no', 'si', 'no']
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
# 8           Amador    66   Jalisco           9.5    50000      0.16    60
#
#     estatura sexo  calorias  salario_neto        IMC Tiene Licencia
# id
# 1       1.75    M      2000        8400.0  22.857143             si
# 2       1.60    F      1800       16800.0  23.437500             no
# 3       1.65    F      2000       12600.0  20.202020             si
# ...

# %%
#Eliminar una columna
tabla_datos.drop(8, inplace=True)#Elimina una fila
tabla_datos.drop(columns=['Tiene Licencia'], inplace= True)#Elimina columna
tabla_datos
# Out:
#             nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo  calorias  salario_neto        IMC
# id
# 1       1.75    M      2000        8400.0  22.857143
# 2       1.60    F      1800       16800.0  23.437500
# 3       1.65    F      2000       12600.0  20.202020
# 4       1.68    F      1400       10080.0  20.549887
# 5       1.70    F      2500       25200.0  22.491349
# ...

# %%
#Obtener el estado, Tabasco, Veracruz y el salario
tabla_datos.loc[tabla_datos['estado'].isin(['Tabasco', 'Veracruz']), ['estado', 'salario']]
# Out:
#       estado  salario
# id
# 1    Tabasco    10000
# 2    Tabasco    20000
# 4   Veracruz    12000
# 5    Tabasco    30000
# 6   Veracruz    18000
# 7   Veracruz    21000

# %%
#filtra el estado de veracruz y tabasco, y mostrar la suma del salario del estado correspondiente.
tabla_datos.loc[tabla_datos['estado'].isin(['Veracruz', 'Tabasco']), ['estado', 'salario']].groupby('estado').sum()
# Out:
#           salario
# estado
# Tabasco     60000
# Veracruz    51000

# %%
#Mostrar los nombres de las columnas del dataframe
#Devuelve una serie conla frecuencia de numeros de repeticiones
tabla_datos.value_counts()
# Out:
# nombre          edad  estado    calificacion  salario  impuesto  peso  estatura  sexo  calorias  salario_neto  IMC
# Ana             30    Tabasco   9.5           20000    0.16      60    1.60      F     1800      16800.0       23.437500    1
# Camila          22    Chiapas   8.9           15000    0.16      55    1.65      F     2000      12600.0       20.202020    1
# Jose            22    Veracruz  5.5           21000    0.16      75    1.66      M     1000      17640.0       27.217303    1
# Juan            25    Tabasco   6.0           10000    0.16      70    1.75      M     2000      8400.0        22.857143    1
# Mish Frances    21    Veracruz  10.0          18000    0.16      50    1.55      F     1600      15120.0       20.811655    1
# Salome          23    Veracruz  6.0           12000    0.16      58    1.68      F     1400      10080.0       20.549887    1
# ...

# %%
#Crear una grafica de pastel para mostrar los salarios por estados, 
#crear la tabla dinamica para mostrar el promedio de salario por estado
tabla1 = pd.pivot_table(tabla_datos, values='salario', index='estado', aggfunc='mean')
tabla1.plot(kind='pie', y='salario', autopct='%1.1f%%', title='salario por estado', startangle=140)
plt.legend(loc='upper right')
plt.axis('equal')
plt.show()

# %%
#Devuelve el numero de elemento del dataframe
tabla_datos.size
# Out:
# 84

# %%
#Renombrar columnas de un dataframe
tabla_datos.rename(columns={'nombre': 'Nombre'})
# Out:
#             Nombre  edad    estado  calificacion  salario  impuesto  peso  \
# id
# 1             Juan    25   Tabasco           6.0    10000      0.16    70
# 2              Ana    30   Tabasco           9.5    20000      0.16    60
# 3           Camila    22   Chiapas           8.9    15000      0.16    55
# 4           Salome    23  Veracruz           6.0    12000      0.16    58
# 5   Sharis Gongora    34   Tabasco           9.0    30000      0.16    65
# 6     Mish Frances    21  Veracruz          10.0    18000      0.16    50
# 7             Jose    22  Veracruz           5.5    21000      0.16    75
#
#     estatura sexo  calorias  salario_neto        IMC
# id
# 1       1.75    M      2000        8400.0  22.857143
# 2       1.60    F      1800       16800.0  23.437500
# 3       1.65    F      2000       12600.0  20.202020
# 4       1.68    F      1400       10080.0  20.549887
# 5       1.70    F      2500       25200.0  22.491349
# ...

# %%
#Cambiar el indice del dataframe
tabla_datos.reindex(index=[1, 3], columns=['Nombre', 'estado'])
# Out:
#     Nombre   estado
# id
# 1      NaN  Tabasco
# 3      NaN  Chiapas
